# %%
import pandas as pd
import seaborn as sns #heat map is part of seaborn library
import os
import matplotlib.pyplot as plt

# %%
os.chdir('<filepath>')

# %%
df = pd.read_csv('50_Startups.csv')
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42  California  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68    New York  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95  California  146121.95
# 11  100671.96        91790.61        249744.55     Florida  144259.40
# ...

# %%
#ran a few debug lines below before the df.corr() as I was getting an error
print(df.head())
# Out:
#    R&D Spend  Administration  Marketing Spend     Profit
# 0  165349.20       136897.80        471784.10  192261.83
# 1  162597.70       151377.59        443898.53  191792.06
# 2  153441.51       101145.55        407934.54  191050.39
# 3  144372.41       118671.85        383199.62  182901.99
# 4  142107.34        91391.77        366168.42  166187.94

# %%
print(os.listdir())
# Out:
# ['.DS_Store', 'Heat Maps.ipynb', '.ipynb_checkpoints', '50_Startups.csv']

# %%
print(df.isnull().sum())
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# Profit             0
# dtype: int64

# %%
print(df.dtypes)
# Out:
# R&D Spend          float64
# Administration     float64
# Marketing Spend    float64
# Profit             float64
# dtype: object

# %%
print(df.select_dtypes(include=['object']).columns)
# Out:
# Index([], dtype='object')

# %%
if len(df.select_dtypes(include=['object']).columns) > 0:
    df = df.select_dtypes(include=['int64', 'float64'])

# %%
df.corr()
# Out:
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.241955         0.724248  0.972900
# Administration    0.241955        1.000000        -0.032154  0.200717
# Marketing Spend   0.724248       -0.032154         1.000000  0.747766
# Profit            0.972900        0.200717         0.747766  1.000000

# %%
#heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation, annot=True, cmap='coolwarm') #annot = True gives the values
plt.show()
#value closer to 1 means better co relation
